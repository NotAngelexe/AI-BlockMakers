# %% [markdown]
# # Ejercicio 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importamos las librerias necesarias para procesamiento de datos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FormatStrFormatter

# %%
# Cargamos nuestro dataset para explorar los datos
path = '/content/drive/MyDrive/Introducción a AI Blockmakers/3 - Machine Learning/car_evaluation.xlsx'
df_car = pd.read_excel(path)
# Visualizamos los 10 primeros datos:
df_car.head(10)
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc
# 5  vhigh   vhigh  2   2    big   low  unacc
# 6  vhigh   vhigh  2   2    big   med  unacc
# 7  vhigh   vhigh  2   2    big  high  unacc
# 8  vhigh   vhigh  2   4  small   low  unacc
# 9  vhigh   vhigh  2   4  small   med  unacc

# %%
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']
df_car.columns = col_names
df_car
# Out:
#      buying  maint  doors persons lug_boot safety  class
# 0     vhigh  vhigh      2       2    small    med  unacc
# 1     vhigh  vhigh      2       2    small   high  unacc
# 2     vhigh  vhigh      2       2      med    low  unacc
# 3     vhigh  vhigh      2       2      med    med  unacc
# 4     vhigh  vhigh      2       2      med   high  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1722    low    low  5more    more      med    med   good
# 1723    low    low  5more    more      med   high  vgood
# 1724    low    low  5more    more      big    low  unacc
# 1725    low    low  5more    more      big    med   good
# 1726    low    low  5more    more      big   high  vgood
#
# [1727 rows x 7 columns]

# %%
df_car.shape
# Out:
# (1727, 7)

# %%
#Visualizamos los tipos de datos
df_car.dtypes
# Out:
# buying      object
# maint       object
# doors       object
# persons     object
# lug_boot    object
# safety      object
# class       object
# dtype: object

# %%
# Verificamos valores faltantes
df_car.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
df_car.describe().T
# Out:
#          count unique    top  freq
# buying    1727      4   high   432
# maint     1727      4   high   432
# doors     1727      4      3   432
# persons   1727      3      4   576
# lug_boot  1727      3    med   576
# safety    1727      3    med   576
# class     1727      4  unacc  1209

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1727 non-null   object
#  1   maint     1727 non-null   object
#  2   doors     1727 non-null   object
#  3   persons   1727 non-null   object
#  4   lug_boot  1727 non-null   object
#  5   safety    1727 non-null   object
#  6   class     1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %% [markdown]
# # Entrenamiento de ML por Random Forest

# %%
# Importamos las librerías necesarias de Scikit-learn
# Robust Scaler es un escalador avanzado se usa para estandarizar los datos:
from sklearn.preprocessing import RobustScaler
# Funciones que ayudan al entrenamiento de ML:
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, RandomizedSearchCV
# RFC es un método que usa árboles de decisión para realizar clasificación:
from sklearn.ensemble import RandomForestClassifier
# Representamos de forma visual el rendimiento de nuestro modelo de clasificación:
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

# %%
#Separamos en Train y Test
X = df_car.drop(['class'], axis=1)
y = df_car['class']

# %%
#30% para test y 70% para train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
#Veamos que tenemos. Por ejemplo, en X_train
X_train.head()
# Out:
#      buying maint  doors persons lug_boot safety
# 1177    med   med  5more       4      big   high
# 585    high  high      3    more    small    med
# 1551    low   med      3       4      med    med
# 727    high   med      4    more      big   high
# 707    high   med      4       2      big    low

# %%
X_train.dtypes
# Out:
# buying      object
# maint       object
# doors       object
# persons     object
# lug_boot    object
# safety      object
# dtype: object

# %%
# !pip install category-encoders

# %%
#Importante: todos nuestros tipos de datos son object, realizamos una transformacion
import category_encoders as ce #pip install category-encoders
encoder = ce.OrdinalEncoder(cols=['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'])

X_train = encoder.fit_transform(X_train)
X_test = encoder.transform(X_test)

# %%
#Verificamos la transformacion
X_train.head(20)
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 1177       1      1      1        1         1       1
# 585        2      2      2        2         2       2
# 1551       3      1      2        1         3       2
# 727        2      1      3        2         1       1
# 707        2      1      3        3         1       3
# 887        1      3      4        2         1       3
# 1000       1      2      2        3         2       1
# 327        4      4      4        3         3       2
# 802        2      4      2        2         2       1
# 832        2      4      3        2         3       1
# 1539       3      1      2        3         2       2
# 1419       3      2      4        1         1       2
# 674        2      1      2        3         2       3
# 177        4      2      3        1         1       2
# 601        2      2      3        3         1       1
# 1374       3      3      3        2         1       2
# ...

# %%
#Importar random forest
rfc = RandomForestClassifier(random_state = 42, max_depth = 3, n_estimators = 10)
rfc_model = rfc.fit(X_train, y_train)

# %%
# TRUE devuelve los puntajes de validación y se almacenan en df scores
scores = pd.DataFrame(cross_validate(rfc, X_train, y_train, cv=10, return_train_score=True))
# Imprimimos el desempeño del modelo de validación cruzada
print("Score promedio de entrenamiento =", scores['train_score'].mean())
# Out:
# Score promedio de entrenamiento = 0.7862413077006332

# %%
# Imprimimmos :
print("Score promedio de validación =", scores['test_score'].mean())
# Score contiene los puntajes individuales de cada pliegue de validación cruzada.
scores
# Out:
# Score promedio de validación = 0.7789738292011019
#    fit_time  score_time  test_score  train_score
# 0  0.022730    0.003790    0.785124     0.812328
# 1  0.020787    0.003266    0.809917     0.807728
# 2  0.022032    0.003027    0.768595     0.789328
# 3  0.020793    0.003171    0.719008     0.765409
# 4  0.019939    0.003098    0.809917     0.787489
# 5  0.020872    0.003124    0.809917     0.789328
# 6  0.020850    0.003055    0.760331     0.777369
# 7  0.019820    0.003145    0.768595     0.776449
# 8  0.019949    0.003146    0.783333     0.770221
# 9  0.020631    0.002934    0.775000     0.786765

# %%
# Visualizamos el rendimiento del modelo sobre nuestros datos de prueba
print(rfc_model.score(X_test, y_test))
# Out:
# 0.7996146435452793

# %%
# Imprimimos una matriz de confusion para observar la cantidad de predicciones correctas e incorrectas
ConfusionMatrixDisplay.from_estimator(rfc_model, X_test, y_test)

# %%
# Visualizacion de las feature importantes
feature_scores = pd.Series(rfc_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
feature_scores
# Out:
# persons     0.448451
# safety      0.418859
# buying      0.077753
# doors       0.024522
# maint       0.016027
# lug_boot    0.014388
# dtype: float64

# %%
#Grafico de barras
sns.barplot(x=feature_scores, y=feature_scores.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()
