# %% [markdown]
# # Reto 1
# Ahora que sabemos realizar análisis básico univariado es momento de poner a prueba los conocimientos adquiridos en la clase para reforzar el aprendizaje

# %%
# Importamos las librerias necesarias para procesamiento de datos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FormatStrFormatter

# %% [markdown]
# Carga el dataset de beer_train.csv y muestra los primeros 15 datos
# TIP: Recuerda cambiar tu ruta de datos

# %%
# Cargamos nuestro dataset para explorar los datos
path = 'beer_train.csv'
df = pd.read_csv(path, sep = ',')

df.head(5)
# Out:
#    Id  Size(L)     OG     FG   ABV     IBU  Color  BoilSize  BoilTime  \
# 0   0    22.71  1.071  1.021  6.51   81.14   6.43     28.39        90
# 1   1     7.57  1.062  1.016  6.14  138.44  15.28      7.57        60
# 2   2    12.00  1.051  1.012  5.17   27.57  14.54     14.00        60
# 3   3    15.00  1.051  1.013  5.01   38.53  26.73     19.00        90
# 4   4    21.77  1.061  1.013  6.25   43.20   4.08     23.66        15
#
#    BoilGravity  Efficiency  MashThickness        SugarScale BrewMethod  \
# 0        1.057        78.0            1.2  Specific Gravity  All Grain
# 1        1.062        35.0            NaN  Specific Gravity    extract
# 2        1.041        65.0            NaN  Specific Gravity       BIAB
# 3        1.040        65.0            3.0  Specific Gravity  All Grain
# 4        1.045        35.0            NaN  Specific Gravity    extract
#
#    PitchRate  PrimaryTemp           Style
# 0        NaN         20.0    American IPA
# 1       0.50         20.0    American IPA
# 2       0.35         20.0   Irish Red Ale
# 3        NaN          NaN  American Stout
# 4       0.75         20.0    American IPA

# %% [markdown]
# Muestra cuántas filas y cuántas columnas contiene el dataset de cervezas (Tamaño del dataset)

# %%
# Escribe tu codigo:
print('Las columnas y renglones son:', df.shape)
# Out:
# Las columnas y renglones son: (24066, 17)

# %% [markdown]
# Obten la información relevante del dataset

# %%
# Escribe tu codigo:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24066 entries, 0 to 24065
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             24066 non-null  int64
#  1   Size(L)        24066 non-null  float64
#  2   OG             24066 non-null  float64
#  3   FG             24066 non-null  float64
#  4   ABV            24066 non-null  float64
#  5   IBU            24066 non-null  float64
#  6   Color          24066 non-null  float64
#  7   BoilSize       24066 non-null  float64
#  8   BoilTime       24066 non-null  int64
#  9   BoilGravity    23130 non-null  float64
#  10  Efficiency     24066 non-null  float64
#  11  MashThickness  14200 non-null  float64
#  12  SugarScale     24066 non-null  object
#  13  BrewMethod     24066 non-null  object
#  14  PitchRate      10932 non-null  float64
#  15  PrimaryTemp    16578 non-null  float64
#  16  Style          24066 non-null  object
# dtypes: float64(12), int64(2), object(3)
# memory usage: 3.1+ MB

# %% [markdown]
# Desglosa la estadística del data frame

# %%
# Escribe tu codigo:
df.describe().T
# Out:
#                  count          mean          std        min        25%  \
# Id             24066.0  12032.500000  6947.400125   0.000000  6016.2500
# Size(L)        24066.0     45.702692   186.624603   1.000000    18.9300
# OG             24066.0      1.367517     2.039252   1.000000     1.0510
# FG             24066.0      1.065335     0.364336   0.598715     1.0110
# ABV            24066.0      6.005748     1.402203   0.000000     5.1800
# IBU            24066.0     52.305999    43.487405   0.000000    28.5225
# Color          24066.0     10.171609     8.726041   0.000000     5.2500
# BoilSize       24066.0     51.652292   199.448712   1.000000    21.0000
# BoilTime       24066.0     63.776573    12.091712   0.000000    60.0000
# BoilGravity    23130.0      1.321495     1.782509   0.000000     1.0400
# Efficiency     24066.0     66.040676    14.131211   0.000000    65.0000
# MashThickness  14200.0      2.143376     1.752144   0.000000     1.5000
# PitchRate      10932.0      0.677991     0.321470   0.000000     0.3500
# PrimaryTemp    16578.0     19.765436     3.645587 -17.780000    18.3300
#
#                      50%        75%          max
# Id             12032.500  18048.750  24065.00000
# Size(L)           20.820     24.000   6102.08000
# OG                 1.058      1.066     23.44500
# FG                 1.013      1.016      7.74577
# ABV                5.880      6.680     49.96000
# IBU               43.310     65.780   1605.83000
# Color              7.280     11.140    108.65000
# BoilSize          28.000     30.000   6454.13000
# BoilTime          60.000     60.000    240.00000
# BoilGravity        1.047      1.057     38.30000
# Efficiency        70.000     75.000    100.00000
# MashThickness      1.500      3.000     54.00000
# PitchRate          0.750      0.750      2.00000
# PrimaryTemp       20.000     21.000     85.00000

# %% [markdown]
#  Encuentra el número de elementos unicos dentro del data frame

# %%
# Escribe tu codigo:
df.nunique()
# Out:
# Id               24066
# Size(L)            672
# OG                 697
# FG                 605
# ABV                980
# IBU               9243
# Color             3142
# BoilSize          1171
# BoilTime            47
# BoilGravity        347
# Efficiency         167
# MashThickness      329
# SugarScale           2
# BrewMethod           4
# PitchRate            9
# PrimaryTemp        134
# Style               11
# dtype: int64

# %% [markdown]
# Crea una copia del data frame y nombrala como df_clean

# %%
# Escribe tu codigo:
df_clean=df.copy()

# %% [markdown]
# Muestra los primeros 10 datos del data frame df_clean

# %%
# Escribe tu codigo:
df_clean.head(10)
# Out:
#    Id  Size(L)     OG     FG   ABV     IBU  Color  BoilSize  BoilTime  \
# 0   0    22.71  1.071  1.021  6.51   81.14   6.43     28.39        90
# 1   1     7.57  1.062  1.016  6.14  138.44  15.28      7.57        60
# 2   2    12.00  1.051  1.012  5.17   27.57  14.54     14.00        60
# 3   3    15.00  1.051  1.013  5.01   38.53  26.73     19.00        90
# 4   4    21.77  1.061  1.013  6.25   43.20   4.08     23.66        15
# 5   5    20.82  1.040  1.008  4.27   30.11  16.32     26.50        60
# 6   6    18.93  1.072  1.015  7.45   29.94   5.44     20.82        60
# 7   7    21.00  1.050  1.009  5.41  111.28   5.78     28.50        60
# 8   8    18.93  1.048  1.008  5.31   13.87   6.08     28.39        60
# 9   9    41.64  1.075  1.017  7.61   70.45   9.29     49.21        60
#
#    BoilGravity  Efficiency  MashThickness        SugarScale BrewMethod  \
# 0        1.057        78.0           1.20  Specific Gravity  All Grain
# 1        1.062        35.0            NaN  Specific Gravity    extract
# 2        1.041        65.0            NaN  Specific Gravity       BIAB
# 3        1.040        65.0           3.00  Specific Gravity  All Grain
# 4        1.045        35.0            NaN  Specific Gravity    extract
# 5        1.032        50.0           1.50  Specific Gravity  All Grain
# 6        1.065        70.0           2.00  Specific Gravity  All Grain
# 7        1.037        65.0           5.00  Specific Gravity  All Grain
# 8        1.032        65.0            NaN  Specific Gravity       BIAB
# 9        1.064        70.0           1.25  Specific Gravity  All Grain
#
#    PitchRate  PrimaryTemp               Style
# 0        NaN        20.00        American IPA
# 1       0.50        20.00        American IPA
# 2       0.35        20.00       Irish Red Ale
# 3        NaN          NaN      American Stout
# 4       0.75        20.00        American IPA
# 5        NaN        26.67  American Amber Ale
# 6       0.35        26.67              Saison
# 7       1.00        19.00   American Pale Ale
# 8       0.50        23.89              Saison
# 9       0.75        17.78        American IPA

# %% [markdown]
# Elimina la columna de Id

# %%
# Escribe tu codigo:
df_clean.drop(columns = ['ID'], inplace=True, errors='ignore')

# %% [markdown]
# Busca todos los datos faltantes del data frame

# %%
# Escribe tu codigo:
datos_faltantes = df_clean.isnull().sum()
datos_faltantes.describe().T
# Out:
# count       17.000000
# mean      1848.470588
# std       4098.016382
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      13134.000000
# dtype: float64

# %% [markdown]
# Elimina las columnas que contengan más del 20% de datos faltantes.
# Recuerda que desde ahora usaremos df_clean y no el df original para no perder los datos originales!!!
#
# Tip : 20% del dataset equivale a 4,813 datos

# %%
# Escribe tu codigo:
limite = len(df_clean) * 0.20
df_clean.dropna(thresh=limite, axis=1, inplace=True)

# %% [markdown]
# Realiza un boxplot de la variable "OG"

# %%
# Escribe tu codigo:
sns.boxplot(df_clean['OG'])
plt.show()

# %% [markdown]
# No se pueden apreciar los datos de una buena forma por lo que vamos a eliminar datos atípicos para obtener una mejor visualización de datos

# %% [markdown]
# Eliminemos datos atípicos para visualizar de una forma más clara los datos:

# %%
df_clean = df_clean[df_clean['OG'] < 1.1]
df_clean.describe().T
# Out:
#                  count          mean          std     min       25%  \
# Id             23319.0  12037.939920  6949.847499   0.000  6016.500
# Size(L)        23319.0     41.130418   165.156064   1.000    18.930
# OG             23319.0      1.058531     0.011715   1.000     1.051
# FG             23319.0      1.013176     0.004045   0.999     1.010
# ABV            23319.0      5.957662     1.214410   0.000     5.180
# IBU            23319.0     52.157592    43.217498   0.000    28.500
# Color          23319.0     10.101405     8.585195   0.000     5.240
# BoilSize       23319.0     46.711175   176.508390   1.000    20.820
# BoilTime       23319.0     63.691282    12.003299   0.000    60.000
# BoilGravity    22401.0      1.051807     0.023310   1.000     1.040
# Efficiency     23319.0     65.920001    14.149769   0.000    65.000
# MashThickness  13633.0      2.128412     1.754120   0.000     1.500
# PitchRate      10599.0      0.675889     0.320409   0.000     0.350
# PrimaryTemp    16089.0     19.766611     3.653008 -17.780    18.330
#
#                      50%        75%        max
# Id             12044.000  18056.500  24065.000
# Size(L)           20.820     23.500   6102.080
# OG                 1.058      1.065      1.099
# FG                 1.013      1.015      1.062
# ABV                5.870      6.660     13.200
# IBU               43.280     65.670   1605.830
# Color              7.260     11.100    108.650
# BoilSize          27.630     30.000   6454.130
# BoilTime          60.000     60.000    240.000
# BoilGravity        1.047      1.055      1.500
# Efficiency        70.000     75.000    100.000
# MashThickness      1.500      3.000     54.000
# PitchRate          0.750      0.750      2.000
# PrimaryTemp       20.000     21.000     85.000

# %% [markdown]
# En nuestra variable "OG", el 75% de nuestros datos se encuentran debajo de 1.066, sin embargo, el valor máximo es de 23.445, eliminemos cualquier valor arriba de 1.1 para poder visualizar los datos de una mejor forma:

# %%
# Codigo de ejemplo:
df_clean = df_clean[df_clean['OG'] < 1.1]
df_clean.describe().T

# %% [markdown]
# Ahora podemos ver con más claridad los datos de la variable "OG"

# %%
# Codigo de ejemplo:
sns.boxplot(df_clean['OG'])

# %% [markdown]
# Realicemos el mismo ejercicio con la variable "IBU" Elimina todos los datos arriba de 125

# %%
# Codigo de ejemplo:
sns.boxplot(df_clean['IBU'])

# %%
# Escribe tu codigo:
sns.boxplot(df_clean['IBU'])
plt.show()

# %% [markdown]
# # OPCIONAL:
# Realiza el balanceo de datos de todas las variables que consideres atípicas

# %%
# Escribe tu codigo:

# %% [markdown]
# # Comenzamos nuestro análisis univariado:

# %% [markdown]
# Realizar un boxplot, histplot y violinplot de nuestra variable OG

# %%
# Escribe tu codigo:

# %%
# Escribe tu codigo:

# %%
# Escribe tu codigo:

# %% [markdown]
# Realiza un boxplot, histplot y violinplot de nuestra variable "IBU"

# %%
# Escribe tu codigo:

# %%
# Escribe tu codigo:

# %%
# Escribe tu codigo:

# %% [markdown]
# Realiza un boxplot de todas las variables numericas

# %%
# Features to plot
features = ['OG', 'FG', 'ABV', 'IBU', 'Color', 'BoilSize', 'BoilTime', 'BoilGravity', 'Efficiency']

# %%
# Escribe tu codigo:

# %% [markdown]
# Realiza un histplot de todas las variables numericas

# %%
# Features to plot
features = ['OG', 'FG', 'ABV', 'IBU', 'Color', 'BoilSize', 'BoilTime', 'BoilGravity', 'Efficiency']

# %%
# Escribe tu codigo:

# %% [markdown]
# Realiza un violinplot de todas las variables numericas

# %%
# Features to plot
features = ['OG', 'FG', 'ABV', 'IBU', 'Color', 'BoilSize', 'BoilTime', 'BoilGravity', 'Efficiency']

# %%
# Escribe tu codigo:
